# %% [markdown]
# ### SPAM Ham Detection

# %%
import random
import nltk
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
## Reading the given dataset
#spam = pd.read_csv("Export_loop-sentiment-pos-neg-train_05112020000000.csv", sep = "\t", names=["label", "text"])
data1 = pd.read_csv("Export_loop-sentiment-pos-neg-train_05112020000000.csv", sep = ",")

# %%
print(data1.head())
# Out:
#       label                                               text
# 0  Negative  No one cares about marketing slides - a techni...
# 1  Positive  Are all three hosts providing storage/capacity...
# 2  Negative  would loved to had managed to get down to the ...
# 3  Negative  Vending machine at work is out of Dasani water...
# 4  Positive  RT @VMwareEdu: Paul Maritz, CEO and President ...

# %%
words_remove = ["i","you","edu","can","lines","what", "there","all","we",
                "one","the","a","an","of","or","in","for","by","on","but","is","in","a","not","with","as",
                "was","if","they","are","this","and","it","have","has","from","at","my","be","by","not","that","to",
                "from","com","org","like","likes","so","said","from","what","told","over","more","other",
                "have","last","with","this","that","such","when","been","says","will","also","where","why",
                "would","today", "in", "you", "r", "d", "u", "hw","wat", "oly", "s", "b", "ht", 
                "rt", "p","the","th", "n", "was","rsvp","http"]

# %%
def cleanlist(df, words_to_remove = words_remove): 
    'removing re-tweet, user mention, hashtags and urls in dataframe level'
   
    # remove emoticons form the dataframe if any
    df['text'] = df['text'].replace(r'<ed>','', regex = True)
    df['text'] = df['text'].replace(r'\B<U+.*>|<U+.*>\B|<U+.*>','', regex = True)
    
    # convert all strings to lowercase
    df['text'] = df['text'].str.lower()
    
    #remove user mentions
    df['text'] = df['text'].replace(r'^(@\w+)',"", regex=True)
    
    #remove 'rt' in the beginning
    #df['text'] = df['text'].replace(r'^(rt @)',"", regex=True)
    
    #remove_symbols 
    df['text'] = df['text'].replace(r'[^a-zA-Z0-9]', " ", regex=True)

    #remove punctuations 
    df['text'] = df['text'].replace(r'[[]!"#$%\'()\*+,-./:;<=>?^_`{|}]+',"", regex = True)

    #remove_URL(x):
    df['text'] = df['text'].replace(r'https.*$', "", regex = True)
    
    #remove words of length 1 or 2 
    df['text'] = df['text'].replace(r'\b[a-zA-Z]{1,2}\b','', regex=True)

    #remove numbers of length 1 or 2 and years
    df['text'] = df['text'].replace(r'\b[0-9]{2,4}\b','', regex=True)
    
    #remove extra spaces in the feedbacks
    df['text'] = df['text'].replace(r'^\s+|\s+$'," ", regex=True)
     
    
    #remove stopwords and words_to_remove
    stop_words = set(stopwords.words('english'))
    mystopwords = [stop_words, "via", words_to_remove]
    
    df['full_text'] = df['text'].apply(lambda x: ' '.join([word for word in x.split() if word not in mystopwords]))
    

    return df

#get the processed feedback data
feedback = cleanlist(data1)

# %%
print(feedback.head(200))
# Out:
#         label                                               text  \
# 0    Negative   one cares about marketing slides    technical...
# 1    Positive  are all three hosts providing storage capacity...
# 2    Negative  would loved  had managed  get down  the camden...
# 3    Negative    vending machine  work  out  dasani water    boo
# 4    Positive  vmwareedu  paul maritz  ceo and president  vmw...
# ..        ...                                                ...
# 195  Positive  the vmware vcloud air disaster recovery campai...
# 196  Negative   the everything admin unfortunately   looked t...
# 197  Positive  only  you remove and  add from the gui   power...
# 198  Negative  yup  had this happen twice  both times  had   ...
# 199  Positive   done both   get more out   person  some  the ...
#
#                                              full_text
# 0    one cares about marketing slides technical how...
# 1    are all three hosts providing storage capacity...
# 2    would loved had managed get down the camden cr...
# 3            vending machine work out dasani water boo
# 4    vmwareedu paul maritz ceo and president vmware...
# ..                                                 ...
# 195  the vmware vcloud air disaster recovery campai...
# 196  the everything admin unfortunately looked thro...
# 197  only you remove and add from the gui powercli ...
# 198  yup had this happen twice both times had with ...
# 199  done both get more out person some the instruc...
#
# [200 rows x 3 columns]

# %%
## Converting the read dataset in to a list of tuples, each tuple(row) contianing the message and it's label
data_set = []
for index,row in feedback.iterrows():
    data_set.append((row['text'], row['label']))

# %%
print(data_set[:50])
# Out:
# [(' one cares about marketing slides    technical how    lot better', 'Negative'), ('are all three hosts providing storage capacity    one  witness   all three have capacity drives  what  you  with the witness   and with them being nucs  just how are you handling capacity and cache      really wondering about two node performance    currently have three hosts but one  them has freenas virtualized and all the disk slots  that host are dedicated for that   could add  das shelf  something  but   very curious what   like running  san with both capacity cache only attached  two nodes and  far  the cluster  aware the third host  strictly only   host  and  that  where   heading   the starwind route going  offer something for performance and reliability with two storage nodes that vmware vsan wouldn   able  match with only two storage nodes ', 'Positive'), ('would loved  had managed  get down  the camden crawl show  but    leetle too far away', 'Negative'), ('vending machine  work  out  dasani water    boo', 'Negative'), ('vmwareedu  paul maritz  ceo and president  vmware  named crn   1 most influential executive ', 'Positive'), ('had few folks ask   you  interested johnny ferguson     vmwarelightwave will  doing vsphere security certificate deep dive  inf4946', 'Positive'), ('get notified  the latest  vsan patch releases and more   virtualblocks explains how ', 'Positive'), ('end  general support  3     6 5 and 6 7 apparently end   5      guessing that  why   probably other reasons   not aware ', 'Negative'), ('placed 4th  funrun today  the   age group could have done better not happy', 'Negative'), ('yup  guys being currently under nda know this for sure ', 'Positive'), ('looks good  printed out for our office ', 'Positive'), (' tried this and  get the corrupt vmx file error', 'Negative'), (' sod   sniff  only trying  pleasure  sorry please you  lady       didn ', 'Negative'), (' 4    did that and they are    but the rest  the stats are all meh  because there   standardization  the industry    hard  decipher what  really  problem ', 'Negative'), ('join    vmware   vforumonline   9 for  keynote  the four technology superpowers   how vmware  pushing the boundaries  what  possible    also  showcasing  variety  other breakout sessions  chats with experts   hands  labs  rsvp ', 'Positive'), (' flight  sfo  bos  wifi  very slow  web works but email doesn   tried two different devices  thought you  like  know ', 'Negative'), ('can not find this   the vcenter server appliance management interface  select syslog    saw something labeled syslog   wouldnt   this   need more steps  what this     loged   the vcsa web admin portal but  idea where the syslog button ', 'Negative'), (' last ditch effort  tried vcenter converter and  managing  maintain  2gbps throughput   windows  located  that same host using  different ssd array   still nowhere near what   capable   but much better   this should only take  hour   and hopefully finish    never could get the native ovf export  finish downloading the vdisk    always stopped the transfer well before reaching 100gb', 'Negative'), ('yes  found that and would agree  except that  was working great until the app volumes agent update   edit  verified    vmfs 5', 'Negative'), ('kristina   any updates from your side    volunteer for beta test       really need that app running  workaround are driving  nuts ', 'Negative'), ('article  about creating  macos virtual machine  fusion  but doesn  explain how ', 'Negative'), ('too bad  thanks for your reply ', 'Negative'), ('going shopping today    favorite thing  and getting new wire for  braces   not  favorite thing', 'Negative'), ('', 'Positive'), (' from what  gathered there was one   was just hopelessly ', 'Negative'), (' dear  what happened        now also  iphone 3gs  owner', 'Negative'), (' huh  paying less tax  not the same  the govt  helping       money ', 'Negative'), (' there  list  clients that support that protocol     looking  buy some new zero thin cli ...

# %%
print(type(data_set))
# Out:
# <class 'list'>

# %%
print(len(data_set))
# Out:
# 1900

# %% [markdown]
# ### Preprocessing

# %%
## initialise the inbuilt Stemmer and the Lemmatizer
stemmer = PorterStemmer()
wordnet_lemmatizer = WordNetLemmatizer()

# %%
def preprocess(document, stem=True):
    'changes document to lower case, and lemmatizes/stems the remainder of the sentence'

    # change sentence to lower case
    document = document.lower()

    # tokenize into words
    words = word_tokenize(document)

    if stem:
        words = [stemmer.stem(word) for word in words]
    else:
        words = [wordnet_lemmatizer.lemmatize(word, pos='v') for word in words]

    # join words to make sentence
    document = " ".join(words)
    



    return document

# %%
## - Performing the preprocessing steps on all messages
messages_set = []
for (message, label) in data_set:
    words_filtered = [e for e in preprocess(message, stem=False).split() if len(e) >= 3]
    messages_set.append((words_filtered, label))

# %%
print(messages_set[:50])
# Out:
# [(['one', 'care', 'about', 'market', 'slide', 'technical', 'how', 'lot', 'better'], 'Negative'), (['all', 'three', 'host', 'provide', 'storage', 'capacity', 'one', 'witness', 'all', 'three', 'have', 'capacity', 'drive', 'what', 'you', 'with', 'the', 'witness', 'and', 'with', 'them', 'nucs', 'just', 'how', 'you', 'handle', 'capacity', 'and', 'cache', 'really', 'wonder', 'about', 'two', 'node', 'performance', 'currently', 'have', 'three', 'host', 'but', 'one', 'them', 'have', 'freenas', 'virtualized', 'and', 'all', 'the', 'disk', 'slot', 'that', 'host', 'dedicate', 'for', 'that', 'could', 'add', 'das', 'shelf', 'something', 'but', 'very', 'curious', 'what', 'like', 'run', 'san', 'with', 'both', 'capacity', 'cache', 'only', 'attach', 'two', 'nod', 'and', 'far', 'the', 'cluster', 'aware', 'the', 'third', 'host', 'strictly', 'only', 'host', 'and', 'that', 'where', 'head', 'the', 'starwind', 'route', 'offer', 'something', 'for', 'performance', 'and', 'reliability', 'with', 'two', 'storage', 'nod', 'that', 'vmware', 'vsan', 'wouldn', 'able', 'match', 'with', 'only', 'two', 'storage', 'nod'], 'Positive'), (['would', 'love', 'have', 'manage', 'get', 'down', 'the', 'camden', 'crawl', 'show', 'but', 'leetle', 'too', 'far', 'away'], 'Negative'), (['vend', 'machine', 'work', 'out', 'dasani', 'water', 'boo'], 'Negative'), (['vmwareedu', 'paul', 'maritz', 'ceo', 'and', 'president', 'vmware', 'name', 'crn', 'most', 'influential', 'executive'], 'Positive'), (['have', 'few', 'folks', 'ask', 'you', 'interest', 'johnny', 'ferguson', 'vmwarelightwave', 'will', 'vsphere', 'security', 'certificate', 'deep', 'dive', 'inf4946'], 'Positive'), (['get', 'notify', 'the', 'latest', 'vsan', 'patch', 'release', 'and', 'more', 'virtualblocks', 'explain', 'how'], 'Positive'), (['end', 'general', 'support', 'and', 'apparently', 'end', 'guess', 'that', 'why', 'probably', 'other', 'reason', 'not', 'aware'], 'Negative'), (['place', '4th', 'funrun', 'today', 'the', 'age', 'group', 'could', 'have', 'better', 'not', 'happy'], 'Negative'), (['yup', 'guy', 'currently', 'under', 'nda', 'know', 'this', 'for', 'sure'], 'Positive'), (['look', 'good', 'print', 'out', 'for', 'our', 'office'], 'Positive'), (['try', 'this', 'and', 'get', 'the', 'corrupt', 'vmx', 'file', 'error'], 'Negative'), (['sod', 'sniff', 'only', 'try', 'pleasure', 'sorry', 'please', 'you', 'lady', 'didn'], 'Negative'), (['that', 'and', 'they', 'but', 'the', 'rest', 'the', 'stats', 'all', 'meh', 'because', 'there', 'standardization', 'the', 'industry', 'hard', 'decipher', 'what', 'really', 'problem'], 'Negative'), (['join', 'vmware', 'vforumonline', 'for', 'keynote', 'the', 'four', 'technology', 'superpowers', 'how', 'vmware', 'push', 'the', 'boundaries', 'what', 'possible', 'also', 'showcasing', 'variety', 'other', 'breakout', 'sessions', 'chat', 'with', 'experts', 'hand', 'labs', 'rsvp'], 'Positive'), (['flight', 'sfo', 'bos', 'wifi', 'very', 'slow', 'web', 'work', 'but', 'email', 'doesn', 'try', 'two', 'different', 'devices', 'think', 'you', 'like', 'know'], 'Negative'), (['can', 'not', 'find', 'this', 'the', 'vcenter', 'server', 'appliance', 'management', 'interface', 'select', 'syslog', 'saw', 'something', 'label', 'syslog', 'wouldnt', 'this', 'need', 'more', 'step', 'what', 'this', 'log', 'the', 'vcsa', 'web', 'admin', 'portal', 'but', 'idea', 'where', 'the', 'syslog', 'button'], 'Negative'), (['last', 'ditch', 'effort', 'try', 'vcenter', 'converter', 'and', 'manage', 'maintain', '2gbps', 'throughput', 'windows', 'locate', 'that', 'same', 'host', 'use', 'different', 'ssd', 'array', 'still', 'nowhere', 'near', 'what', 'capable', 'but', 'much', 'better', 'this', 'should', 'only', 'take', 'hour', 'and', 'hopefully', 'finish', 'never', 'could', 'get', 'the', 'native', 'ovf', 'export', 'finish', 'download', 'the', 'vdisk', 'always', 'stop', 'the', 'transfer', 'well', 'before', 'reach', '100gb'], 'Negative'), (['yes', 'find', 'that', 'and', 'would', 'agree', 'except', 'that', 'work', 'great', 'until', 'th ...

# %% [markdown]
# ### Preparing to create features

# %%
## - creating a single list of all words in the entire dataset for feature list creation

def get_words_in_messages(messages):
    all_words = []
    for (message, label) in messages:
      all_words.extend(message)
    return all_words

# %%
## - creating a final feature list using an intuitive FreqDist, to eliminate all the duplicate words
## Note : we can use the Frequency Distribution of the entire dataset to calculate Tf-Idf scores like we did earlier.

def get_word_features(wordlist):

    #print(wordlist[:10])
    wordlist = nltk.FreqDist(wordlist)
    word_features = wordlist.keys()
    return word_features

# %%
## - creating the word features for the entire dataset
word_features = get_word_features(get_words_in_messages(messages_set))
print(len(word_features))
# Out:
# 5199

# %% [markdown]
# ### Preparing to create a train and test set

# %%
## - creating slicing index at 80% threshold
sliceIndex = int((len(messages_set)*.8))

# %%
## - shuffle the pack to create a random and unbiased split of the dataset
random.shuffle(messages_set)

# %%
train_messages, test_messages = messages_set[:sliceIndex], messages_set[sliceIndex:]

# %%
len(train_messages)
len(test_messages)
# Out:
# 380

# %% [markdown]
# ### Preparing to create feature maps for train and test data

# %%
## creating a LazyMap of feature presence for each of the 8K+ features with respect to each of the SMS messages
def extract_features(document):
    document_words = set(document)
    features = {}
    for word in word_features:
        features['contains(%s)' % word] = (word in document_words)
    return features

# %%
## - creating the feature map of train and test data

training_set = nltk.classify.apply_features(extract_features, train_messages)
testing_set = nltk.classify.apply_features(extract_features, test_messages)

# %%
print(training_set[:5])
# Out:
# [({'contains(one)': True, 'contains(care)': False, 'contains(about)': False, 'contains(market)': False, 'contains(slide)': False, 'contains(technical)': False, 'contains(how)': False, 'contains(lot)': False, 'contains(better)': False, 'contains(all)': False, 'contains(three)': False, 'contains(host)': True, 'contains(provide)': False, 'contains(storage)': False, 'contains(capacity)': False, 'contains(witness)': False, 'contains(have)': True, 'contains(drive)': False, 'contains(what)': True, 'contains(you)': True, 'contains(with)': True, 'contains(the)': True, 'contains(and)': True, 'contains(them)': False, 'contains(nucs)': False, 'contains(just)': True, 'contains(handle)': True, 'contains(cache)': False, 'contains(really)': False, 'contains(wonder)': False, 'contains(two)': False, 'contains(node)': False, 'contains(performance)': False, 'contains(currently)': False, 'contains(but)': False, 'contains(freenas)': False, 'contains(virtualized)': False, 'contains(disk)': False, 'contains(slot)': False, 'contains(that)': True, 'contains(dedicate)': False, 'contains(for)': True, 'contains(could)': False, 'contains(add)': False, 'contains(das)': False, 'contains(shelf)': False, 'contains(something)': True, 'contains(very)': False, 'contains(curious)': False, 'contains(like)': True, 'contains(run)': False, 'contains(san)': False, 'contains(both)': False, 'contains(only)': False, 'contains(attach)': False, 'contains(nod)': False, 'contains(far)': True, 'contains(cluster)': True, 'contains(aware)': False, 'contains(third)': False, 'contains(strictly)': False, 'contains(where)': False, 'contains(head)': False, 'contains(starwind)': False, 'contains(route)': False, 'contains(offer)': False, 'contains(reliability)': False, 'contains(vmware)': False, 'contains(vsan)': False, 'contains(wouldn)': False, 'contains(able)': False, 'contains(match)': False, 'contains(would)': False, 'contains(love)': False, 'contains(manage)': False, 'contains(get)': True, 'contains(down)': False, 'contains(camden)': False, 'contains(crawl)': False, 'contains(show)': False, 'contains(leetle)': False, 'contains(too)': False, 'contains(away)': False, 'contains(vend)': False, 'contains(machine)': False, 'contains(work)': False, 'contains(out)': False, 'contains(dasani)': False, 'contains(water)': False, 'contains(boo)': False, 'contains(vmwareedu)': False, 'contains(paul)': False, 'contains(maritz)': False, 'contains(ceo)': False, 'contains(president)': False, 'contains(name)': False, 'contains(crn)': False, 'contains(most)': False, 'contains(influential)': False, 'contains(executive)': False, 'contains(few)': False, 'contains(folks)': False, 'contains(ask)': False, 'contains(interest)': False, 'contains(johnny)': False, 'contains(ferguson)': False, 'contains(vmwarelightwave)': False, 'contains(will)': True, 'contains(vsphere)': False, 'contains(security)': False, 'contains(certificate)': False, 'contains(deep)': False, 'contains(dive)': False, 'contains(inf4946)': False, 'contains(notify)': False, 'contains(latest)': False, 'contains(patch)': False, 'contains(release)': False, 'contains(more)': True, 'contains(virtualblocks)': False, 'contains(explain)': False, 'contains(end)': False, 'contains(general)': False, 'contains(support)': False, 'contains(apparently)': False, 'contains(guess)': False, 'contains(why)': False, 'contains(probably)': True, 'contains(other)': False, 'contains(reason)': False, 'contains(not)': True, 'contains(place)': False, 'contains(4th)': False, 'contains(funrun)': False, 'contains(today)': False, 'contains(age)': True, 'contains(group)': True, 'contains(happy)': False, 'contains(yup)': False, 'contains(guy)': True, 'contains(under)': False, 'contains(nda)': False, 'contains(know)': False, 'contains(this)': True, 'contains(sure)': True, 'contains(look)': False, 'contains(good)': False, 'contains(print)': False, 'contains(our)': True, 'contains(office)': False, 'contains(try)': True, 'contains(corrupt)': False, 'contains(vmx)': False, 'conta ...

# %%
print('Training set size : ', len(training_set))
print('Test set size : ', len(testing_set))
# Out:
# Training set size :  1520
# Test set size :  380

# %% [markdown]
# ### Training

# %%
## Training the classifier with NaiveBayes algorithm
spamClassifier = nltk.NaiveBayesClassifier.train(training_set)

# %% [markdown]
# ### Evaluation

# %%
## - Analyzing the accuracy of the training set
print(nltk.classify.accuracy(spamClassifier, training_set))
# Out:
# 0.9223684210526316

# %%
## Analyzing the accuracy of the test set
print(nltk.classify.accuracy(spamClassifier, testing_set))
# Out:
# 0.7052631578947368

# %%
m = pd.read_csv("sentiment-eval.csv", sep = ",")

## Testing a example message with our newly trained classifier

print('Classification result : ', spamClassifier.classify(extract_features(m)))
# Out:
# Classification result :  Negative

# %%
## Testing a example message with our newly trained classifier
#m = 'CONGRATULATIONS!! As a valued account holder you have been selected to receive a £900 prize reward! Valid 12 hours only.'
#print('Classification result : ', spamClassifier.classify(extract_features(m.split())))

# %%
## Priting the most informative features in the classifier
print(spamClassifier.show_most_informative_features(30))
# Out:
# Most Informative Features
#           contains(http) = True           Positi : Negati =     44.9 : 1.0
#          contains(error) = True           Negati : Positi =      9.6 : 1.0
#            contains(own) = True           Positi : Negati =      9.0 : 1.0
#          contains(sleep) = True           Negati : Positi =      8.8 : 1.0
#       contains(congrats) = True           Positi : Negati =      8.4 : 1.0
#           contains(damn) = True           Negati : Positi =      8.1 : 1.0
#  contains(documentation) = True           Negati : Positi =      8.1 : 1.0
#           contains(join) = True           Positi : Negati =      7.8 : 1.0
#        contains(vmworld) = True           Positi : Negati =      6.8 : 1.0
#           contains(free) = True           Positi : Negati =      6.8 : 1.0
#           contains(most) = True           Positi : Negati =      6.8 : 1.0
#         contains(easier) = True           Positi : Negati =      6.7 : 1.0
#     contains(enterprise) = True           Positi : Negati =      6.7 : 1.0
#         contains(future) = True           Positi : Negati =      6.7 : 1.0
#           contains(bite) = True           Positi : Negati =      6.6 : 1.0
#           contains(shit) = True           Negati : Positi =      6.5 : 1.0
#          contains(thank) = True           Positi : Negati =      6.5 : 1.0
#           contains(page) = True           Negati : Positi =      6.4 : 1.0
#           contains(vsan) = True           Positi : Negati =      6.3 : 1.0
#            contains(sad) = True           Negati : Positi =      6.2 : 1.0
#           contains(quot) = True           Negati : Positi =      5.8 : 1.0
#           contains(able) = True           Positi : Negati =      5.7 : 1.0
#       contains(hardware) = True           Positi : Negati =      5.6 : 1.0
#          contains(amaze) = True           Positi : Negati =      5.5 : 1.0
#     contains(appreciate) = True           Positi : Negati =      5.5 : 1.0
#         contains(attend) = True           Positi : Negati =      5.5 : 1.0
#       contains(consider) = True           Positi : Negati =      5.5 : 1.0
#        contains(however) = True           Positi : Negati =      5.5 : 1.0
#       contains(sessions) = True           Positi : Negati =      5.5 : 1.0
#          contains(veeam) = True           Positi : Negati =      5.5 : 1.0
# None

# %%
## storing the classifier on disk for later usage
import pickle
f = open('nb_spam_classifier.pickle', 'wb')
pickle.dump(spamClassifier,f)
print('Classifier stored at ', f.name)
f.close()
# Out:
# Classifier stored at  nb_spam_classifier.pickle
